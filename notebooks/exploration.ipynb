# %%
import pandas as pd
import matplotlib.pyplot as plt

#Se carga los datos limpios

data_path = "../data/processed/cleaned_products.csv"
df = pd.read_csv(data_path)

#Analisis y visualizacion

print("Basic Statistics")
print(df.describe())

#Histograma de precios.

plt.hist(df["price"], bins=20, edgecolor="black")
plt.title("Distribucion de precios")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()

#Productos mas caros.

print("Productos mas Caros: ")
highestPrices = df.nlargest(5,"price")
print(highestPrices)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Basic Statistics
#              price
# count     3.000000
# mean    521.956667
# std     516.066005
# min     102.990000
# 25%     233.725000
# 50%     364.460000
# 75%     731.440000
# max    1098.420000
# Productos mas Caros:
#                title                                        description  \
# 0   Dell Inspiron...  Dell Inspiron 15 (7567) Black, 15.6" FHD, Core...
# 1  Hewlett Packar...  Hewlett Packard 250 G6 Dark Ash Silver, 15.6" ...
# 2      Asus MeMO Pad                            7" screen, Android, 8GB
#
#      price
# 0  1098.42
# 1   364.46
# 2   102.99
